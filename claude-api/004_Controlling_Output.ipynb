# %% [markdown]
# Structuring Output

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-5"

# %%
def chat(messages, system=None, temperature=None, stop_sequences=None):
    params = {
        "model": model,
        "messages": messages,
        "max_tokens": 1024,
    }
    
    if stop_sequences:
        params["stop_sequences"] = stop_sequences
    
    if system:
        params["system"] = system
        
    if temperature:
        # Claude Sonnet 5 rejects the temperature parameter entirely
        params["temperature"] = temperature
        
    message = client.messages.create(**params)
    return next(block.text for block in message.content if block.type == "text")

# %%
def add_user_message(messages, content):
    messages.append({"role": "user", "content": content})
    return messages

def add_assistant_message(messages, content):
    messages.append({"role": "assistant", "content": content})
    return messages

# %%
# Solve without system prompt
from IPython.display import Markdown

# %% [markdown]
# EXERCISE:
#
# - Use message prefilling and stop sequences only to get 3 different commands in a single response
# - There shouldn't be any comments or explanation
# - Hint: Message prefilling isn't limited to just characters like ```

# %%
messages = []

prompt = """
Generate 3 different AWS CLI commands. Each should be different and very short.
"""

add_user_message(messages, prompt)

text = chat(messages)
text.strip()
# Out:
# 'Here are 3 short AWS CLI commands:\n\n1. **List S3 buckets:**\n```\naws s3 ls\n```\n\n2. **List EC2 instances:**\n```\naws ec2 describe-instances\n```\n\n3. **Get current IAM user:**\n```\naws sts get-caller-identity\n```'

# %%
Markdown(text)
# Out:
# Here are 3 short AWS CLI commands:
#
# 1. **List S3 buckets:**
# ```
# aws s3 ls
# ```
#
# 2. **List EC2 instances:**
# ```
# aws ec2 describe-instances
# ```
#
# 3. **Get current IAM user:**
# ```
# aws sts get-caller-identity
# ```

# %%
messages = []

prompt = """
Generate 3 different AWS CLI commands. Each should be different and very short.
"""

# system = """
# You are a helpful assistant that provides AWS CLI commands in response to user requests.
# Don't add any comments or explanations to responses. Only provide the commands themselves, each on a new line.
# """

add_user_message(messages, prompt)
add_assistant_message(messages, "```")

text = chat(messages, stop_sequences=["```"])
text.strip()
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[13], line 15
#      11
#      12 add_user_message(messages, prompt)
#      13 add_assistant_message(messages, "```")
#      14
# ---> 15 text = chat(messages, stop_sequences=["```"])
#      16 text.strip()
#
# Cell In[12], line 18, in chat(messages, system, temperature, stop_sequences)
#      14     if temperature:
#      15         # Claude Sonnet 5 rejects the temperature parameter entirely
#      16         params["temperature"] = temperature
#      17
# ---> 18     message = client.messages.create(**params)
#      19     return next(block.text for block in message.content if block.type == "text")
#
# File ~/Documents/Personal/Projects/anthropic-courses/claude-api/.venv/lib/python3.12/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~/Documents/Personal/Projects/anthropic-courses/claude-api/.venv/lib/python3.12/site-packages/anthropic/resources/messages/messages.py:1048, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, user_profile_id, extra_headers, extra_query, extra_body, timeout)
#    1041     warnings.warn(
#    1042         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1043         UserWarning,
#    1044         stacklevel=3,
#    1045     )
#    1047 extra_headers = {**strip_not_given({"anthropic-user-profile-id": user_profile_id}), **(extra_headers or {})}
# -> 1048 return self._post(
#    1049     "/v1/messages",
#    1050     body=maybe_transform(
#    1051         {
#    1052             "max_tokens": max_tokens,
#    1053             "messages": messages,
#    1054             "model": model,
#    1055             "cache_control": cache_control,
#    1056             "container": container,
#    1057             "inference_geo": inference_geo,
#    1058             "metadata": metadata,
#    1059             "output_config": output_config,
#    1060             "service_tier": service_tier,
#    1061             "stop_sequences": stop_sequences,
#    1062             "stream": stream,
#    1063             "system": system,
#    1064             "temperature": temperature,
#    1065             "thinking": thinking,
#    1066             "tool_choice": tool_choice,
#    1067             "tools": tools,
#    1068             "top_k": top_k,
#    1069             "top_p": top_p,
#    1070         },
#    1071         message_create_params.MessageCreateParamsStreaming
#    1072         if stream
#    1073         else message_create_params.MessageCreateParamsNonStreaming,
#    1074     ),
#    1075     options=make_request_options(
#    1076         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1077     ),
#    1078     cast_to=Message,
#    1079     stream=stream or False,
#    1080     stream_cls=Stream[RawMessageStreamEvent],
#    1081 )
#
# File ~/Documents/Personal/Projects/anthropic-courses/claude-api/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/Personal/Projects/anthropic-courses/claude-api/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1195, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192     if not response.is_closed:
#    1193         response.read()
# -> 1195     raise self._make_status_error_from_response(response) from None
#    1197 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'This model does not support assistant message prefill. The conversation must end with a user message.'}, 'request_id': 'req_011Ce2hWzJj6jsNF7xepsgg7'}
