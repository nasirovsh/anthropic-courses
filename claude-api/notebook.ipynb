# %% [markdown]
# # Building with the Claude API
#
# Course link: https://anthropic-partners.skilljar.com/claude-with-the-anthropic-api

# %% [markdown]
# Install packages

# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in ./.venv/lib/python3.12/site-packages (0.122.0)
# Collecting python-dotenv
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.12/site-packages (from anthropic) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.12/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in ./.venv/lib/python3.12/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./.venv/lib/python3.12/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./.venv/lib/python3.12/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio<2,>=1 in ./.venv/lib/python3.12/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in ./.venv/lib/python3.12/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.4)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load antropic API key from .env file

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-5"

# %%
#Make a request to the Claude API

response = client.messages.create(
    model="claude-sonnet-5",
    max_tokens=1024,
    messages=[
        {
            "role": "user", 
            "content": "What is quantum computing ? Answer in one sentence."
        }
    ]
)
print(response.content[0].text)
# Out:
# Quantum computing is a type of computing that uses the principles of quantum mechanics—such as superposition and entanglement—to process information in ways that can solve certain complex problems much faster than classical computers.

# %%
response
# Out:
# Message(id='msg_011Ce22wpKreYBK5yKEj5AMy', container=None, content=[TextBlock(citations=None, text='Quantum computing is a type of computing that uses the principles of quantum mechanics—such as superposition and entanglement—to process information in ways that can solve certain complex problems much faster than classical computers.', type='text')], model='claude-sonnet-5', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=24, output_tokens=65, output_tokens_details=OutputTokensDetails(thinking_tokens=0), server_tool_use=None, service_tier='standard'))

# %%
response = client.messages.create(
    model="claude-sonnet-5",
    max_tokens=1024,
    messages=[
        {
            "role": "user", 
            "content": "Add another sentence."
        }
    ]
)
print(response.content[0].text)
# Out:
# I'd be happy to help you add a sentence! However, I don't see any existing text or context in your message to add to.
#
# Could you please share:
# - The sentence or paragraph you'd like me to add to
# - Any context about the topic or tone you're going for
# - Where you'd like the new sentence placed (beginning, middle, end)
#
# Once you provide that, I can help craft a sentence that fits well with your content.

# %%
def add_user_message(messages, content):
    messages.append({"role": "user", "content": content})
    return messages

def add_assistant_message(messages, content):
    messages.append({"role": "assistant", "content": content})
    return messages

def chat_with_claude(messages):
    response = client.messages.create(
        model="claude-sonnet-5",
        max_tokens=1024,
        messages=messages
    )
    return next(block.text for block in response.content if block.type == "text")

# %%
messages = []

add_user_message(messages, "What is quantum computing ? Answer in one sentence.")

answer = chat_with_claude(messages)

add_assistant_message(messages, answer)

add_user_message(messages, "Add another sentence.")

final_answer = chat_with_claude(messages)

print(final_answer)
# Out:
# Quantum computing is a type of computation that harnesses the principles of quantum mechanics—such as superposition and entanglement—to process information in ways that can solve certain problems much faster than classical computers. Instead of using classical bits that represent either a 0 or a 1, it uses qubits, which can exist in multiple states simultaneously, enabling massively parallel processing for specific tasks like cryptography, optimization, and molecular simulation.

# %%
messages = []

while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit"]:
        break
    add_user_message(messages, user_input)
    answer = chat_with_claude(messages)
    add_assistant_message(messages, answer)
    print(f"Claude: {answer}")
# Out:
# Claude: **1 + 1 = 2**
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 8
#       4     user_input = input("You: ")
#       5     if user_input.lower() in ["exit", "quit"]:
#       6         break
#       7     add_user_message(messages, user_input)
# ----> 8     answer = chat_with_claude(messages)
#       9     add_assistant_message(messages, answer)
#      10     print(f"Claude: {answer}")
#
# Cell In[11], line 15, in chat_with_claude(messages)
#      11         model=model,
#      12         max_tokens=1024,
#      13         messages=messages
#      14     )
# ---> 15     return response.content[0].text
#
# File ~/Documents/Personal/Projects/anthropic-courses/claude-api/.venv/lib/python3.12/site-packages/pydantic/main.py:1042, in BaseModel.__getattr__(self, item)
#    1039     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#    1040 else:
#    1041     # this is the current error
# -> 1042     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'ThinkingBlock' object has no attribute 'text'
